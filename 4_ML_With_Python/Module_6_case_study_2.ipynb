# %% [markdown]
# ## Objectives:
# ## 1.Provide the learner some more practice for exploratory data analysis.
# ## 2.Equip the learner to fit and evaluate a linear regression model.

# %%
## Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1.Load the data from “cereal.csv” and plot histograms of sugar and vitamin content across different cereals.
# [Hint: Extract values of a specific column using their labels and use hist method of pyplot ]

# %%
## Reading data from file into dataframe

df=pd.read_csv(r"./datasets/cereal.csv")

# %%
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [77 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
## Plotting histogram
plt.figure(figsize=(10,6))
plt.hist(df["sugars"], bins=17, alpha=1, label="Sugar Content")
plt.xlabel("Sugar", size=14)
plt.ylabel("Count", size=14)
plt.title("Sugar Content Histogram")
plt.legend(loc='upper right')
plt.show()

plt.figure(figsize=(10,6))
plt.hist(df["vitamins"], bins=15, alpha=1, label="Vitamin Content")
plt.xlabel("Vitamins", size=14)
plt.ylabel("Count", size=14)
plt.title("Vitamin Content Histogram")
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### 2. The names of the manufactures are coded using alphabets, create a new column with their full name using the below mapping.
# ### 'N': 'Nabisco',
# ### 'Q': 'Quaker Oats',
# ### 'K': 'Kelloggs',
# ### 'R': 'Raslston Purina',
# ### 'G': 'General Mills' ,
# ### 'P' :'Post' ,
# ### 'A':'American Home Foods Products'
# ### Create a bar plot where each manufacturer is on the y axis and the height of the bars depict the number of cereals manufactured by them.
# [Hint: Try using countplot this time or bar method of pyplot]

# %%
mf = {'N': 'Nabisco',
'Q': 'Quaker Oats',
'K': 'Kelloggs',
'R': 'Raslston Purina',
'G': 'General Mills' ,
'P' :'Post' ,
'A':'American Home Foods Products'}

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df["manufacturer"] = df["mfr"].map(mf)

# %%
df.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
# 8                  Bran Chex   R    C        90        2    1     200    4.0
# 9                Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    5.0       6     280        25      3    1.00  0.33  68.402973
# 1    8.0       8     135         0      3    1.00  1.00  33.983679
# 2    7.0       5     320        25      3    1.00  0.33  59.425505
# 3    8.0       0     330        25      3    1.00  0.50  93.704912
# 4   14.0       8      -1        25      3    1.00  0.75  34.384843
# 5   10.5      10      70        25      1    1.00  0.75  29.509541
# 6   11.0      14      30        25      2    1.00  1.00  33.174094
# 7   18.0       8     100        25      3    1.33  0.75  37.038562
# 8   15.0       6     125        25      1    1.00  0.67  49.120253
# 9   13.0       5     190        25      3    1.00  0.67  53.313813
#
#       manufacturer
# 0          Nabisco
# 1      Quaker Oats
# 2         Kelloggs
# 3         Kelloggs
# 4  Raslston Purina
# 5    General Mills
# 6         Kelloggs
# 7    General Mills
# 8  Raslston Purina
# 9             Post

# %%
df_mf = df.groupby("manufacturer").count()["name"]

# %%
df_mf = df_mf.reset_index()

# %%
df_mf
# Out:
#                    manufacturer  name
# 0  American Home Foods Products     1
# 1                 General Mills    22
# 2                      Kelloggs    23
# 3                       Nabisco     6
# 4                          Post     9
# 5                   Quaker Oats     8
# 6               Raslston Purina     8

# %%
## Bar plot 

fig = plt.figure(figsize = (18, 8))
 
# creating the bar plot
plt.bar(df_mf["manufacturer"], df_mf["name"], width = 0.4)
plt.xlabel("Manufacturer")
plt.ylabel("Count of Cereals")
plt.title("Cereals produced by each manufacturer")
plt.show()

# %% [markdown]
# ### 3. Extract the rating as your target variable ‘y’ and all numerical parameters as your predictors ‘x’. Separate 25% of your data as test set.

# %%
## importing test train split package
from sklearn.model_selection import train_test_split

# %%
col = ["calories","protein","fat","sodium","fiber","carbo","sugars","potass","vitamins","shelf","weight","cups"]

# %%
X=df[col]

# %%
Y=df["rating"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (57, 12) (20, 12) (57,) (20,)

# %% [markdown]
# ### 4. Fit a linear regression module and measure the mean squared error on test dataset.
# [ Hint: Explore linear models and metrics section of sklearn documentation]

# %%
## impporting Lingreesion regressor
from sklearn.linear_model import LinearRegression

# %%
regr = LinearRegression()
  
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regr.predict(X_test)

# %%
## importing model metrics
from sklearn.metrics import mean_squared_error

# %%
print(mean_squared_error(y_test,y_pred))
# Out:
# 1.6102511851373614e-13

# %% [markdown]
# #### The model has good MSE since it closer to zero
